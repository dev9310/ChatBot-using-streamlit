# %%
# !pip install --upgrade openai
# Out:
# ...
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/125.2 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/125.2 kB ? eta -:--:--
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
genai.configure(api_key='AIzaSyCi2c-H5RHN-OO4XOa3lCCcqsL_lxT6fNg')

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content("""models/gemini-1.0-pro-latest
models/gemini-1.0-pro
models/gemini-pro
models/gemini-1.0-pro-001
models/gemini-1.0-pro-vision-latest
models/gemini-pro-vision
models/gemini-1.5-pro-latest
models/gemini-1.5-pro-001
models/gemini-1.5-pro
models/gemini-1.5-flash-latest
models/gemini-1.5-flash-001
models/gemini-1.5-flash
Which one is better for chat bot application and free and how much response is free 

""")

# %%
to_markdown(response.text)
# Out:
# > You're asking about the best Gemini model for chatbot applications, specifically focusing on **free access**.  Let's break down the models and their suitability:
# >
# > **Important Note:** Google hasn't released detailed pricing information for Gemini models.  As of right now, it appears that all of them are currently under development, and some are in limited beta access.  This means the information below is based on current understanding and could change.
# >
# > **Model Comparison:**
# >
# > * **Gemini-1.0-Pro-Latest, Gemini-1.0-Pro, Gemini-Pro:**  These are likely the most advanced models. "Pro" often indicates a higher level of capability, including better text generation, reasoning, and understanding.  However, they are likely NOT free.
# > * **Gemini-1.0-Pro-001:**  This indicates a version of the Gemini Pro model. It's possible it might be in a free tier or have limited free usage, but this is currently unclear.
# ...
