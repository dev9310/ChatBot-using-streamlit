# %%
# !pip install --upgrade openai
# Out:
# ...
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/125.2 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/125.2 kB ? eta -:--:--
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
#      --------- --------------------------- 30.7/125.2 kB 163.8 kB/s eta 0:00:01
# ...

# %%
setx OPENAI_API_KEY "sk-proj-4XTwMSiyUYX6t5uRrt92T3BlbkFJtA35iaqheexpXircsifc"
# Out:
#   Cell In[2], line 1
#     setx OPENAI_API_KEY "sk-proj-4XTwMSiyUYX6t5uRrt92T3BlbkFJtA35iaqheexpXircsifc"
#          ^
# SyntaxError: invalid syntax
